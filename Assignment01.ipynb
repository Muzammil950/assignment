# %%
list = [2, 33.4, True, "sheikh", (2,3), [2,3], {'a':3}, {2,3}]

# %%
for el in list:
    print(f"(element : {el}  |  Type : {type(el)}")
# Out:
# (element : 2  |  Type : <class 'int'>
# (element : 33.4  |  Type : <class 'float'>
# (element : True  |  Type : <class 'bool'>
# (element : sheikh  |  Type : <class 'str'>
# (element : (2, 3)  |  Type : <class 'tuple'>
# (element : [2, 3]  |  Type : <class 'list'>
# (element : {'a': 3}  |  Type : <class 'dict'>
# (element : {2, 3}  |  Type : <class 'set'>

# %%
list2 = list(range(1, 26))
for num in list2:
    if num % 3 == 0:
        print(f"{num} is divisible by 3")
    else:
        print(f"{num} is not divisible by 3")
# Out:
# 1 is not divisible by 3
# 2 is not divisible by 3
# 3 is divisible by 3
# 4 is not divisible by 3
# 5 is not divisible by 3
# 6 is divisible by 3
# 7 is not divisible by 3
# 8 is not divisible by 3
# 9 is divisible by 3
# 10 is not divisible by 3
# 11 is not divisible by 3
# 12 is divisible by 3
# 13 is not divisible by 3
# 14 is not divisible by 3
# 15 is divisible by 3
# 16 is not divisible by 3
# 17 is not divisible by 3
# 18 is divisible by 3
# 19 is not divisible by 3
# 20 is not divisible by 3
# 21 is divisible by 3
# 22 is not divisible by 3
# 23 is not divisible by 3
# 24 is divisible by 3
# 25 is not divisible by 3

# %%
x = 5
y = 3
x = y
y = x + 2
print(x,y)
# Out:
# 3 5

# %%
a = 10 
b = 5
c = a // b
d = a % b
print(c,d)
# Out:
# 2 0

# %%
x = 5
y = 10
x = y
y =20
print(x)
# Out:
# 10

# %%
x = 5 
y = 10
if x > y :
    print("x is greater")
else:
    print("y is greater")
# Out:
# y is greater

# %%
sum = 0 
for i in range(1,6):
    sum += i
    print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15

# %%
count = 0
while count < 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
x = 10
if x > 5:
    print("x is greater then 5")
elif x == 5:
    print("x is equal to 5")
else:
    print("x is less then 5")
# Out:
# x is greater then 5
