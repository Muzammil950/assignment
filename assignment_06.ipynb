# %%
# write a programmme to input 2 number and print their sum.

# %%
a = float(input("enter num1 : " ))
b = float(input("enter num2 : "))
print("sum of : ",a + b)
# Out:
# enter num1 :  23
# enter num2 :  43
# sum of :  66.0

# %%
#write a programme to input side of square and print it area.

# %%
side = int(input("enter side squrare : "))
print("area of square :", side*side)
# Out:
# enter side squrare :  4
# area of square : 16

# %%
side = float(input("enter side square : "))
print("area of square : ", side*side)
# Out:
# enter side square :  3
# area of square :  9.0

# %%
#write a programme to input 2 floating point number and print their average.

# %%
a = float(input("enter num1 : "))
b = float(input("enter num2 : "))
print("average of : ", (a + b)/2)
# Out:
# enter num1 :  4
# enter num2 :  5
# average of :  6.5

# %%
#write a programme to input 2 int numbers, a and b. print True if a greater then or equal to b. if not print print False.

# %%
a = int(input("enter first num : "))
b = int(input("enter second num : "))
print(a >= b)
# Out:
# enter first num :  3
# enter second num :  4
# False

# %%
#write to programme to check if a number entered by the user is odd or even.

# %%
num = int(input("enter num :"))
if num % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# enter num : 3
# odd

# %%
#write a programme find the greater of 3 number entered by the  user

# %%
a = int(input("enter a : "))
b = int(input("enter b : "))
c = int(input("enter c : "))
if a >= b and  a >= c:
    print("a is greater")
elif b>=c :
    print("b is greater")
else:
    print("c is greater")
# Out:
# enter a :  4
# enter b :  5
# enter c :  6
# c is greater

# %%
#write a programme to check if a list contains a palindrom of elements.

# %%
list = [1,2,1]
list_copy = list.copy()
list_copy.reverse()

if list_copy == list:
    print("palindrom")
else:
    ("not palindrom")
# Out:
# palindrom

# %%
#write a programme to ask the user to enter names of their 3 movies name and store them in a list.

# %%
movies = []
movies.append(input("enter 1st mov : "))
movies.append(input("enter 2nd mov : "))
movies.append(input("enter 3rd mov : "))
print(movies)
# Out:
# enter 1st mov :  i dont
# enter 2nd mov :  like
# enter 3rd mov :  movie
# ['i dont', 'like ', 'movie']
